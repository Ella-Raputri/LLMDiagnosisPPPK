# %%
import pandas as pd

# %%
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')
df4 = pd.read_csv('df4.csv')
df5 = pd.read_csv('df5.csv')

# %%
df_combined = pd.concat([df2, df3, df4, df5], ignore_index=True)
df_combined.to_csv('results.csv')
df_combined.describe()
# Out:
#        Unnamed: 0         No  LLM_JUDGE_Claude_avg_4  LLM_JUDGE_Claude_best_4  \
# count   45.000000  45.000000               45.000000                45.000000
# mean    22.000000  23.000000                0.383543                 0.668222
# std     13.133926  13.133926                0.107090                 0.206522
# min      0.000000   1.000000                0.132000                 0.330000
# 25%     11.000000  12.000000                0.300000                 0.500000
# 50%     22.000000  23.000000                0.366000                 0.600000
# 75%     33.000000  34.000000                0.450000                 0.800000
# max     44.000000  45.000000                0.600000                 1.000000
#
#        LLM_JUDGE_Claude_all_4  LLM_JUDGE_Claude_avg_3.5  \
# count               45.000000                 45.000000
# mean                 0.586667                  0.369483
# std                  0.210896                  0.145666
# ...

# %%
for col, avg in df_combined.mean(numeric_only=True).items():
    print(f"Average of '{col}': {avg:.2f}")
# Out:
# Average of 'Unnamed: 0': 22.00
# Average of 'No': 23.00
# Average of 'LLM_JUDGE_Claude_avg_4': 0.38
# Average of 'LLM_JUDGE_Claude_best_4': 0.67
# Average of 'LLM_JUDGE_Claude_all_4': 0.59
# Average of 'LLM_JUDGE_Claude_avg_3.5': 0.37
# Average of 'LLM_JUDGE_Claude_best_3.5': 0.79
# Average of 'LLM_JUDGE_Claude_all_3.5': 0.35
# Average of 'LLM_JUDGE_Qwen_avg_4': 0.25
# Average of 'LLM_JUDGE_Qwen_best_4': 0.56
# Average of 'LLM_JUDGE_Qwen_all_4': 0.41
# Average of 'LLM_JUDGE_Qwen_avg_3.5': 0.18
# Average of 'LLM_JUDGE_Qwen_best_3.5': 0.53
# Average of 'LLM_JUDGE_Qwen_all_3.5': 0.23
# Average of 'LLM_JUDGE_GPT_avg_4': 0.36
# Average of 'LLM_JUDGE_GPT_best_4': 0.64
# Average of 'LLM_JUDGE_GPT_all_4': 0.53
# Average of 'LLM_JUDGE_GPT_avg_3.5': 0.27
# Average of 'LLM_JUDGE_GPT_best_3.5': 0.72
# Average of 'LLM_JUDGE_GPT_all_3.5': 0.30
# Average of 'LLM_JUDGE_Deepseek_RAG_avg_4': 0.36
# Average of 'LLM_JUDGE_Deepseek_RAG_best_4': 0.62
# Average of 'LLM_JUDGE_Deepseek_RAG_all_4': 0.50
# ...
