# %%
import numpy as np
import pandas as pd
from bert_score import score as bert_score_fn
from bleurt import score as bleurt_score_module

# %%
df = pd.read_csv('../cleaning_before_eval/ready_to_eval.csv')
df.head()
# Out:
#     No                                           Question  \
# 0  1.0  Pasien mengalami demam pada waktu malam. Sebel...
# 1  2.0  Pasien mengalami buang air besar cair lebih da...
# 2  3.0  Pasien datang dengan keluhan demam selama 6 ha...
# 3  4.0  Pasien menderita demam disertai munculnya brun...
# 4  5.0  Pasien nyeri dada sejak 4 jam lalu seperti ter...
#
#                                            Dr Answer  \
# 0        Demam Tifoid 70%, Demam Berdarah Dengue 30%
# 1  Gastroenteritis (GE) Akut 70%, Intoleransi Lak...
# 2                                            DBD 80%
# 3  Infeksi Bakteri/Virus (Sistemik) 50%, Infeksi ...
# 4  Angina Pekrotis 80%, Infark Miokard Akut (Sera...
#
#                                        Claude Answer  \
# 0  Demam Tifoid, Leptospirosis, Demam Berdarah De...
# 1  Gastroenteritis (GE) Akut, Disentri, Infeksi E...
# 2  Demam Tifoid, Malaria, DBD, Leptospirosis, Inf...
# 3  DBD, Infeksi Bakteri/Virus (Sistemik), Infeksi...
# 4  Angina Pekrotis, Infark Miokard Akut (Serangan...
#
#                                          Qwen Answer  \
# 0  Demam Biasa, Dispepsia, Asma, Infeksi Saluran ...
# 1  Diare Akut, Gastroenteritis, Dispepsia, Infeks...
# 2  Demam Biasa, Dispepsia, Asma, Demam Dengue, Lu...
# 3  Demam Biasa, Dispepsia, Asma, Infeksi Lokal, A...
# 4  Infark Miokard Akut (Serangan Jantung), Dispep...
#
#                                           GPT Answer  \
# 0  Demam Biasa, Demam Tifoid, Demam Berdarah Deng...
# 1  Gastroenteritis Akut, Infeksi Escherichia coli...
# 2  Demam Berdarah Dengue, Demam Tifoid, Malaria, ...
# 3  Infeksi Kulit (Dermatitis atau Selulitis), Kej...
# 4  Angina Pekrotis, Infark Miokard, Penyakit Musk...
#
#                                  Deepseek RAG Answer  \
# 0  Demam Tifoid (Typhoid Fever), Malaria, Leptosp...
# 1  Gastroenteritis Akut, Keracunan Makanan, Infek...
# 2  Demam Berdarah Dengue (DBD), Demam Tifoid, Lep...
# 3  Infeksi Bakteri (Selulitis), Reaksi Alergi (De...
# 4  Angina Pectoris (Kardiovaskular), Infark Mioka...
#
#                              Deepseek non RAG Answer  \
# 0  Malaria, Infeksi Saluran Kemih (ISK) atau Piel...
# 1  Gastroenteritis Akut, Keracunan Makanan, Koler...
# 2  Demam Berdarah Dengue (DBD) / Dengue Fever, Ch...
# 3  Erisipelas (Infeksi Bakteri pada Kulit dan Jar...
# 4  Infark Miokard Akut (Serangan Jantung), Angina...
#
#                                   Claude Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, saya akan...
# 1  Berdasarkan informasi klinis yang diberikan, s...
# 2  Berdasarkan informasi yang diberikan, saya aka...
# 3  Berdasarkan informasi klinis yang diberikan, s...
# 4  Berdasarkan informasi yang diberikan dalam kon...
#
#                                     Qwen Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, yaitu dem...
# 1  Berdasarkan gejala yang disampaikan, yaitu bua...
# 2  Berdasarkan gejala yang disampaikan, yaitu dem...
# 3  Berdasarkan gejala yang disampaikan, yaitu dem...
# 4  Berdasarkan gejala yang disampaikan, yaitu nye...
#
#                                      GPT Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, yaitu dem...
# 1  Berdasarkan informasi yang diberikan, pasien m...
# 2  Berdasarkan keluhan yang disampaikan oleh pasi...
# 3  Berdasarkan informasi yang diberikan, pasien m...
# 4  Berdasarkan informasi yang diberikan, pasien m...
#
#                             Deepseek RAG Full Answer  \
# 0  Berdasarkan gejala yang dialami pasien, yaitu ...
# 1  Berdasarkan informasi yang diberikan, pasien m...
# 2  Berdasarkan keluhan pasien yang meliputi demam...
# 3  ### Analisis Gejala dan Kemungkinan Diagnosis\...
# 4  ### Analisis Gejala\n\nPasien mengeluhkan nyer...
#
#                         Deepseek non RAG Full Answer
# 0  Berdasarkan gejala yang Anda sebutkan—demam pa...
# 1  Berdasarkan gejala yang Anda deskripsikan—diar...
# 2  Berdasarkan gejala yang Anda sebutkan—demam ≥6...
# 3  Berdasarkan gejala dan temuan pemeriksaan yang...
# 4  Berdasarkan gejala nyeri dada seperti terhimpi...

# %%
answer_lists = {}
answer_columns = [col for col in df.columns if col.endswith(' Answer')]

for col_name in answer_columns:
    if (col_name.endswith(' Full Answer')): continue
    model = col_name.removesuffix(' Answer')
    answers = df[col_name].tolist()
    answer_lists[model] = answers

# %%
answer_lists
# Out:
# {'Dr': ['Demam Tifoid 70%, Demam Berdarah Dengue 30%',
#   'Gastroenteritis (GE) Akut 70%, Intoleransi Laktosa 30%',
#   'DBD 80%',
#   'Infeksi Bakteri/Virus (Sistemik) 50%, Infeksi Jaringan Lunak (Selulitis) 70%',
#   'Angina Pekrotis 80%, Infark Miokard Akut (Serangan Jantung) 80%',
#   'Asma 100%, Bronkitis Akut 70%, Penyakit Paru Obstruktif Kronik 50%',
#   'Bronkitis Akut 100%',
#   'Bronkitis Akut 80%, Asma Bronkial 50%',
#   'Dispepsia 100%, Pneumonia 50%, Infeksi Saluran Pernapasan 50%',
#   'Dispepsia 80%, refluk Gastroesofagus (GERD) 90%',
#   'Gastroenteritis Akut 70%, Infeksi saluran pencernaan 50%',
#   'Batu Ginjal 70%, Kolik Renal 80%, Ganguan Saluran kemih 100%, Ureterolitiasis 70%',
#   'Peritonitis 50%, Infeksi Saluran Pencernaan Akut 70%, Obstruksi Usus 70%',
#   'Kolesistitis Akut 70%, Dispepsia 70%',
#   'Appendisitis Akut 70%, Kolika Abdominalis 80%',
#   'Dispepsia 80%, Infeksi Saluran Pernapasan Atas 80%',
#   'Infeksi Saluran pernapasan atas 70%, Influenza 80%',
#   'Infeksi Saluran Pernapasan atas 80%, Bronkitis 50%',
#   'Influenza 80%, Infeksi Saluran Pernapasan atas 80%',
#   'Infeksi Saluran Pernapasan 80%',
#   'Demam Dengue 50%, DBD 30%, Demam Umum/Infeksi Virus 80%',
#   'Dengue Fever 70%',
#   'Awal Infeksi Virus 70%',
#   'Hipertensi stage 1 100%, Post Syncope Kelainan Non Neurologis 50%, Post Syncope Kelainan Neurologis 50%',
#   'Cedera Kepala Ringan (CKR) 100%, Luka Terbuka/Robek (Vulnus Laceratum) 100%',
#   'Luka Terbuka/Robek (Vulnus Laceratum) 100%',
#   'Post Trauma 100%',
#   'CKR disebabkan oleh Vertigo 90%, Luka Terbuka/Robek (Vulnus Laceratum) 100%, Gangguan Keseimbangan Neurologis Lain 70%',
#   'Luka Lecet (Vulnus Excoriatum) 100%',
#   'Luka Bakar /Burn Injury (Derajat III) 70%, Luka Bakar /Burn Injury (Derajat IIb) 50%',
#   'Demam Biasa (Common Fever) 70%, Demam Dengue 30%',
#   'Influenza 70%, Infeksi saluran pernapasan atas 50%',
#   'Gastroenteritis(GE) 80%, Influenza 70%',
#   'Infeksi saluran pernapasan atas 50%, Influenza 70%',
#   'Influenza 50%, Tonsilitis  70%, Faringitis 100%',
#   'Infeksi saluran pernapasan atas 70%, Pneumonia 50%',
#   'Gastritis 70%, Refluks Asam Lambung (GERD) 90%, Tukak Lambung (Ulkus Gaster) 70%',
#   'Dispepsia 70%, Gastritis akut 70%, Reflux Gastroesofageal (GERD) 90%',
#   'Dispepsia 70%, Gastritis 70%, Gastroesofageal reflux Desiease (GERD) 90%',
#   'Dispepsia 70%, Gastritis akut 70%',
#   'Asma Bronkial  70%, Bronkitis Akut 50%, Infeksi saluran pernapasan atas 50%',
#   'Dispepsia 70%, Gastritis Akut 70%, Refleks Asam Lambung (GERD) 90%',
#   'Gangguan Saluran Pencernaan 50%, Dispepsia 70%',
#   'Bronkitis Akut 50%, Infeksi saluran pernapasan 70%, Gangguan kardiovaskular 50%',
#   'Asma Bronkial  70%, Bronkitis Akut 50%'],
#  'Claude': ['Demam Tifoid, Leptospirosis, Demam Berdarah Dengue, Hepatitis A, Infeksi Saluran Kemih',
#   'Gastroenteritis (GE) Akut, Disentri, Infeksi Escherichia coli, Kolitis Infeksius, Intoleransi Laktosa',
#   'Demam Tifoid, Malaria, DBD, Leptospirosis, Infeksi Virus',
#   'DBD, Infeksi Bakteri/Virus (Sistemik), Infeksi Jaringan Lunak (Selulitis), Sindrom Demam dengan Komplikasi Neurologis, Arthritis Infeksius',
#   'Angina Pekrotis, Infark Miokard Akut (Serangan Jantung), Iskemia Jantung, Sindrom Dada Tidak Stabil, Diseksi Aorta',
#   'Asma, Bronkitis Akut, Pnemonia, Penyakit Paru Obstruktif Kronik, Tension Pneumothorax',
#   'Pneumonia Komunitas, Bronkitis Akut, Asma, Infeksi Saluran Pernapasan Atas, PPOK (Penyakit Paru Obstruktif Kronik)',
#   'Bronkitis Akut, Pneumonia , Asma Bronkial, Kardiopulmonal, Gangguan Respirasi Lain',
#   'Dispepsia, Pneumonia, Infeksi Saluran Pernapasan, Gastroenteritis , Asthma',
#   'Dispepsia, Gastritis Akut, Ulkus Peptikum, Apendisitis, refluk Gastroesofagus (GERD)',
#   'Gastroenteritis Akut, Infeksi saluran pencernaan, Dispepsia, Demam Tifoid, Dehidrasi',
#   'Batu Ginjal, Kolik Renal, Ganguan Saluran kemih, Ureterolitiasis, Dispepsia sekunder',
#   'Disentri, Peritonitis, Infeksi Saluran Pencernaan Akut, Apendisitis, Obstruksi Usus',
#   'Peritonitis, Kolesistitis Akut, Apendisitis Akut, Dispepsia, Obstruksi Usus',
#   'Peritonitis, Appendisitis Akut, Dispepsia, Gastroenteritis, Kolika Abdominalis',
#   'Demam Tifoid, Gastroenteritis Akut, Dispepsia, Infeksi Saluran Pernapasan Atas, Demam Dengue',
#   'COVID-19, Infeksi Saluran pernapasan atas , Influenza, Demam dengue, Malaria',
#   'Demam Tifoid, Infeksi Saluran Pernapasan atas, Demam Biasa, Flu, Bronkitis',
#   'Demam Tifoid, Influenza, Demam Dengue, Pneumonia, Infeksi Saluran Pernapasan atas',
#   'DBD, Demam Tifoid, Malaria, Infeksi Saluran Pernapasan, Demam Biasa (Infeksi Virus)',
#   'Demam Dengue, DBD, Malaria, Infeksi Saluran Pernapasan, Demam Umum/Infeksi Virus',
#   'Demam Tifoid, Demam biasa, Awal Fase Influenza, Dengue Fever, Infeksi saluran kemih',
#   'DBD, Awal Infeksi Virus, Infeksi Saluran Pernapasan, gangguan sistemik, Demam biasa',
#   'Hipertensi stage 1, Gangguan kardiovaskular, Vertigo/Gangguan Keseimbangan, Serangan Ringan Hipertensi, Gangguan Metabolik, Post Syncope Kelainan Non Neurologis, Post Syncope Kelainan Neurologis',
#   'Trauma kepala ringan = Cedera Kepala Ringan (CKR), Cedera Kepala Ringan (CKR), Potensi Kerusakan Neurologis, Luka Terbuka/Robek (Vulnus Laceratum), -',
#   'Luka bakar superfisial (derajat I), Luka Terbuka/Robek (Vulnus Laceratum), Dermatitis kontak iritan, Abrasio Kulit, Luka Infeksi Potensial',
#   'Post Trauma , -, -, -',
#   'CKR disebabkan oleh Vertigo, Luka Terbuka/Robek (Vulnus Laceratum), Gangguan Keseimbangan Neurologis Lain, Hipotensi Ortostatik, Gangguan Pendengaran, Gangguan Neurologis Ringan',
#   'Definisi Vulnus Excoriasi, Luka Lecet (Vulnus Excoriatum), -, -, -',
#   'Luka Bakar /Burn Injury (Derajat III) , Luka Bakar /Burn Injury (Derajat IIb), -, -, -',
#   'Demam Biasa (Common Fever), Infeksi Sistemik, Infeksi Saluran Pernapasan, Demam Dengue, Influenza',
#   'Demam Biasa (Common Cold), Influenza, Demam Berdarah Dengue (DBD), Infeksi saluran pernapasan atas, Demam Tifoid',
#   'Gastroenteritis(GE), Influenza, Demam Biasa (Infeksi Saluran Pernapasan), Disentri, Tifoid',
#   'Demam Biasa (Viral), Demam dengue, Infeksi saluran pernapasan atas, Influenza , COVID-19',
#   'Demam biasa, Influenza, Infeksi saluran pernapasan atas, Asma, Tonsilitis , Faringitis ',
#   'Demam tifoid, DBD, Infeksi saluran pernapasan atas, Influenza, Pneumonia',
#   'Dispepsia, Gastritis , Refluks Asam Lambung (GERD), Tukak Lambung (Ulkus Gaster) , Sindrom dispepsia fungsional',
#   'Dispepsia, Gastritis akut, Reflux Gastroesofageal (GERD), Ulkus peptikum, Gastroenteritis',
#   'Dispepsia, Gastritis , Gastroesofageal reflux Desiease (GERD), Hipertensi dengan Komplikasi Kardiovaskuler, Gangguan Pencernaan Fungsional',
#   'Dispepsia , Gastritis akut, Appendisitis, Peritonitis, Gastroenteritis',
#   'Status Asmatikus (Asma Akut Berat), Asma Bronkial, Bronkitis Akut, Infeksi saluran pernapasan atas, -',
#   'Dispepsia, Penyakit Kardiovaskular, Gastritis Akut , Refleks Asam Lambung (GERD), Gangguan Sistem Pencernaan',
#   'Gangguan Saluran Pencernaan, Dispepsia , Asma, Kolik Renal, Penyakit Jantung',
#   'Asma, Bronkitis Akut , Laringitis, Infeksi saluran pernapasan, Serangan Alergi Pernapasan, Gangguan kardiovaskular',
#   'Status Asmatikus (Asma Akut Berat), Asma Eksaserbasi, Asma Bronkial, Bronkitis Akut, -'],
#  'Qwen': ['Demam Biasa, Dispepsia, Asma, Infeksi Saluran Pernapasan Atas, Infeksi Saluran Kemih',
#   'Diare Akut, Gastroenteritis, Dispepsia, Infeksi Saluran Pencernaan, Intoleransi Laktosa',
#   'Demam Biasa, Dispepsia, Asma, Demam Dengue, Lupus Eritematosus Sistemik (LES)',
#   'Demam Biasa, Dispepsia, Asma, Infeksi Lokal, Artritis ',
#   'Infark Miokard Akut (Serangan Jantung), Dispepsia, Asma, Pneumonia , Kostokondritis',
#   'Asma, Pneumonia, Dispepsia, Demam biasa, Kardiomiopati',
#   'Asma, Infeksi Saluran Pernapasan Atas (ISPA), Dispepsia, Demam biasa, Hipertensi',
#   'Asma, Dispepsia, Pneumonia, Anemia, Kardiomiopati',
#   'Dispepsia, Demam Biasa, Asma, Infeksi saluran pencernaan, Infeksi saluran pernapasan',
#   'Dispepsia Fungsional, Gastritis, Reflux Asam Lambung (GERD), Asma, Penyakit Jantung',
#   'Gastroenteritis Akut, Dispepsia Fungsional, Infeksi Saluran Pencernaan, Demam Biasa, Asma',
#   'Infeksi Saluran Kemih (ISK) Akut, Batuk Ginjal, Dispepsia, Apendisitis, Radikulopati Lumbal',
#   'Dispepsia, Apendisitis, Demam Biasa, Asma, Obstruksi Usus',
#   'Dispepsia, Obstruksi Usus, Kolitis, Penyakit Crohn, Divertikulitis',
#   'Dispepsia Fungsional, Endometriosis, Salpingitis, Apendisitis, Penyakit Inflamasi Usus (PIU)',
#   'Dispepsia Fungsional, Demam Biasa, Asma, Infeksi Saluran Pencernaan Akut, Infeksi Saluran Pernapasan Atas',
#   'Demam Biasa, Pneumonia, Influenza, Asma, Dispepsia',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Akut (ISPA), Pneumonia',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Akut (ISPA), Pneumonia',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Atas (ISPA), Infeksi Saluran Pernapasan Bawah (ISPB)',
#   'Demam Biasa, Pneumonia, Infeksi Saluran Kemih (ISK), Malaria, Infeksi Saluran Pernapasan Akut (ISPA)',
#   'Demam biasa, Influenza, Dispepsia, Asma, Infeksi Saluran Pernapasan Akut (ISPA)',
#   'Demam Biasa, Dispepsia, Asma, Infeksi Saluran Pernapasan Atas (ISPA), Dehidrasi',
#   'Hipertensi Akut, Dispepsia, Demam Biasa, Asma, Vertigo',
#   'Luka Robek (Laceration), Kepala Cedera Ringan (Mild Head Injury), Konkusi (Concussion), Fraktur Cranial (Skull Fracture), Hematoma Epidural (Epidural Hematoma)',
#   'Luka Robek (Laceration), Nyeri Akibat Luka, Infeksi Luka, Dispepsia, Demam Biasa',
#   'Luka Ringan atau Kontusio, Fraktur Tulang, Kepala Cedera, Dispepsia, Demam Biasa',
#   'Benign Paroxysmal Positional Vertigo (BPPV), Dispepsia, Hipotensi Ortostatik, Demam Biasa, Asma',
#   'Luka Lecet Ringan, Luka Lecet Berat, Fraktur Tulang, Kontusio, Luka Bakar',
#   'Luka Bakar, Fraktur Tulang, Luka Tertusuk, -, -',
#   'Demam Biasa, Dispepsia, Asma, Infeksi Virus, Infeksi Bakteri',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Atas (ISPA), Pneumonia',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pencernaan Akut, Infeksi Saluran Pernapasan Akut',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Atas (ISPA), Pneumonia',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Atas (ISPA), Flu (Influenza)',
#   'Demam Biasa, Asma, Dispepsia, Infeksi Saluran Pernapasan Atas (ISPA), Pneumonia',
#   'Dispepsia, Gastroesophageal Reflux Disease (GERD), Penyakit Jantung, Penyakit Tiroid, Penyakit Hati',
#   'Dispepsia Fungsional, Gastritis Akut, Ulkus Peptikum, Penyakit Refluks Gastroesofagus (GERD), Penyakit Jantung Koroner (PJK)',
#   'Dispepsia, Refluks Gastroesofageal (GERD), Penyakit Jantung Koroner, Penyakit Tiroid, Penyakit Hati',
#   'Dispepsia Fungsional, Penyakit Maag Akut (Gastritis Akut), Penyakit Asam Lambung (GERD), Penyakit Pankreas Akut (Pankreatitis Akut), Penyakit Usus Buntu (Apendisitis)',
#   'Asma Exacerbation, Pneumonia, Bronkitis Akut, Asma, Demam Biasa',
#   'Dispepsia Fungsional, Gastroesophageal Reflux Disease (GERD), Asma, Penyakit Jantung Koroner (PJK), Anxiety Disorder',
#   'Dispepsia, Asma, Penyakit Jantung Koroner (PJK), Gastritis, Penyakit Refluks Gastroesofageal (GERD)',
#   'Asma, Dispepsia, Pneumonia, Sinusitis Akut, Demam Biasa',
#   'Asma Exacerbation (Pemburukan Asma), Dispepsia, Pneumonia (Radang Paru-paru), Bronkitis Akut, Demam Biasa'],
#  'GPT': ['Demam Biasa, Demam Tifoid, Demam Berdarah Dengue, Leptospirosis, Malaria',
#   'Gastroenteritis Akut, Infeksi Escherichia coli, Diare Akibat Keracunan Makanan, Infeksi Virus Norovirus, Disentri',
#   'Demam Berdarah Dengue, Demam Tifoid, Malaria, Infeksi Saluran Pernafasan Atas (ISPA) dengan Ruam, Infeksi Virus (misalnya, Rubella atau Campak)',
#   'Infeksi Kulit (Dermatitis atau Selulitis), Kejang Demam, Penyakit Autoimun (Misalnya Artritis Reumatoid), Reaksi Alergi, Artritis ',
#   'Angina Pekrotis, Infark Miokard, Penyakit Muskuloskeletal, Pneumonia , GERD',
#   'Asma, Penyakit Paru Obstruktif Kronis, Pnemonia, Emboli Paru, Tension Pneumothorax',
#   'ISPA, Bronkitis Akut, Asma, Pneumonia, Diabetes Insipidus atau Infeksi Saluran Kemih (ISK)',
#   'Asma, Pneumonia , Penyakit Paru Obstruktif Kronis (PPOK), Emboli Paru, Pneumotoraks',
#   'Dispepsia, Demam Biasa, Gastroenteritis, Gastroenteritis , Asma',
#   'Dispepsia, Gastritis Akut, Ulser Peptikum, Penyakit Jantung Koroner, refluk Gastroesofagus (GERD)',
#   'Gastroenteritis, Intoleransi makanan atau alergi, Dispepsia, Obstruksi usus, Infeksi saluran pencernaan',
#   'Pielonefritis Akut, Kolik Renal, Herniasi Diskus, Infeksi Saluran Kemih, Kondisi Musculoskeletal',
#   'Obstruksi Usus, Peritonitis, Disentri, Apendisitis Akut, Gastritis Akut atau Ulkus Peptikum',
#   'Kolesistitis Akut, Ulkus Peptikum, Gastritis Akut, Dispepsia, Obstruksi Usus',
#   'Appendicitis (Radang Usus Buntu), Dispepsia, Penyakit Radang Panggul (Pelvic Inflammatory Disease), Kista Ovarium Pecah, Obstruksi Usus',
#   'Demam Biasa, Gastroenteritis, Demam Tifoid, Infeksi Saluran Pernapasan Atas (ISPA), Dispepsia',
#   'Demam Biasa, Infeksi Saluran pernapasan atas, Influenza, Sinusitis Akut, Alergi atau Rhinitis Alergi',
#   'Demam Tifoid, Infeksi Saluran Pernapasan atas, Demam Biasa, Pneumonia, Bronkitis Akut',
#   'Demam Biasa, Influenza, Pneumonia, COVID-19, Infeksi Saluran Pernapasan Atas',
#   'Demam Biasa, Demam Tifoid, Malaria, Infeksi saluran pernapasan atas, Demam Berdarah Dengue (DBD)',
#   'Demam Biasa, DBD, Demam Berdarah Dengue, Infeksi Saluran Pernapasan Atas (ISPA), Infeksi Lainnya',
#   'Demam Tifoid, Demam biasa, Malaria, Infeksi Saluran Pernapasan Atas (ISPA), Dengue Fever (Demam Berdarah)',
#   'Demam Biasa, Infeksi virus , Demam Dengue, Kejang Demam, Penyakit Menular Lain',
#   'Hipertensi, Kejang atau Sinkop, Gastroenteritis, Penyakit Jantung, Dispepsia',
#   'Trauma Kepala, Luka Robek, Patah Tulang Tengkorak, Kepala Memar (Contusio Capitis), Pendarahan Intrakranial',
#   'Luka Robek (Laceration), Luka Terbuka (Open Wound), Luka Kontusio (Contusion), Infeksi Luka, Fraktur Tersembunyi (Hidden Fracture)',
#   'Fraktur, Sprain atau Strain, Kontusi, Cedera Kepala, Cedera Tulang Belakang',
#   'Benign Paroxysmal Positional Vertigo (BPPV), Migren, Vestibular Neuritis, Penyakit Meniere, Cervical Vertigo',
#   'Luka terbuka, Nyeri, Pembengkakan, Risiko infeksi, -',
#   'Luka Bakar, Cedera Jaringan Lunak, Fraktur, Sindrom Kompartemen, Infeksi',
#   'Demam Biasa, Demam Berdarah Dengue (DBD), Infeksi Saluran Pernapasan Atas, Malaria, Infeksi Virus Lain',
#   'Demam Biasa, Infeksi Saluran Pernapasan Atas (ISPA), Influenza, COVID-19, Alergi atau Rhinitis Alergi',
#   'Demam Biasa, Gastroenteritis Akut, Infeksi saluran pernapasan atas, Diare Akut Infektif, Demam Tifoid',
#   'Asma, Demam biasa, Infeksi Saluran Pernapasan Atas (ISPA), Flu (Influenza), Alergi atau Rhinitis Alergi',
#   'Demam Biasa, Infeksi Saluran Pernapasan Atas (ISPA), Tonsilitis, COVID-19, Flu (Influenza)',
#   'Demam Berdarah Dengue, Demam Biasa, Infeksi Saluran Pernapasan Atas (ISPA), Asma, Pneumonia',
#   'Angina Pektoris, Dispepsia, Gastroesophageal Reflux Disease (GERD), Penyakit Jantung Koroner, Pankreatitis',
#   'Ulser Peptikum, Dispepsia, Gastritis Akut, Penyakit Refluks Gastroesofagus (GERD), Kolesistitis',
#   'Penyakit Jantung Koroner (PJK), Dispepsia, Gastritis, Refluks Gastroesofageal (GERD), Ulser Peptikum',
#   'Ulser Peptikum, Dispepsia, Gastritis Akut, Kolesistitis, Pankreatitis',
#   'Bronkitis Akut, Asma, Infeksi Saluran Pernapasan Atas (ISPA), Reaksi Alergi, Pneumonia',
#   'Gastritis Akut, Dispepsia, Gastroesophageal Reflux Disease (GERD), Angina Pektoris, Infark Miokard (Serangan Jantung)',
#   'Dispepsia, Penyakit Jantung Koroner, Asma, Gastritis atau Ulkus Peptikum, Kolesistitis',
#   'Asma, Bronkitis Akut, Pneumonia, Infeksi Saluran Pernapasan Atas (ISPA), Alergi atau Reaksi Iritasi',
#   'Asma, Status Asmatikus, Bronkitis Akut, Pneumonia, Reaksi Alergi atau Iritasi'],
#  'Deepseek RAG': ['Demam Tifoid (Typhoid Fever), Malaria, Leptospirosis, Infeksi Saluran Kemih (ISK), Sepsis',
#   'Gastroenteritis Akut, Keracunan Makanan, Infeksi Bakteri (misalnya E. coli atau Shigella), Dispepsia, Irritable Bowel Syndrome (IBS)',
#   'Demam Berdarah Dengue (DBD), Demam Tifoid, Leptospirosis, Malaria, Infeksi Virus Lain (misalnya, Chikungunya atau Zika)',
#   'Infeksi Bakteri (Selulitis), Reaksi Alergi (Dermatitis Kontak), Infeksi Virus (Herpes Zoster), Penyakit Autoimun (Lupus Eritematosus Sistemik), Infeksi Jamur (Tinea Corporis)',
#   'Angina Pectoris (Kardiovaskular), Infark Miokard Akut (Kardiovaskular), Kolik Renal (Ginjal dan Saluran Kemih), Penyakit Refluks Gastroesofageal (GERD), Gangguan Muskuloskeletal',
#   ' Asma, Bronkitis Akut, Pneumotoraks, Gagal Jantung Kongestif (CHF), Penyakit Paru Obstruktif Kronis (PPOK)',
#   'Infeksi Saluran Pernapasan Akut (ISPA), Bronkitis Akut, Pneumonia, Asma, Diabetes Mellitus dengan Komplikasi Infeksi',
#   'Asma, Pneumonia, Emboli Paru, Gagal Jantung Akut, Penyakit Paru Obstruktif Kronis (PPOK)',
#   'Dispepsia, Gastroenteritis, Pneumonia, Gastritis Akut, Refluks Gastroesofageal (GERD)',
#   'Dispepsia, Gastroesophageal Reflux Disease (GERD), Ulkus Peptikum, Gastritis, Pankreatitis Akut',
#   'Gastroenteritis Akut, Dispepsia, Dehidrasi Berat, Keracunan Makanan, Hipertensi Krisis',
#   'Batu Ginjal (Nefrolitiasis), Infeksi Saluran Kemih (ISK), Kolik Ureter, Pielonefritis Akut, Dispepsia dengan Referred Pain',
#   'Obstruksi Usus, Peritonitis, Apendisitis Akut, Kolik Renal (Batu Ginjal), Gastroenteritis Akut',
#   'Dispepsia, Obstruksi Usus Parsial, Gastritis Akut, Ulkus Peptikum, Pankreatitis Akut',
#   'Apendisitis Akut, Sindrom Iritasi Usus Besar (IBS), Infeksi Saluran Kemih (ISK), Kista Ovarium yang Pecah atau Torsi Ovarium, Dispepsia',
#   'Gastroenteritis Akut, Dispepsia, Demam Tifoid (Tifus Abdominalis), Infeksi Saluran Pernapasan Atas (ISPA), Demam Biasa (Viral Fever)',
#   'Infeksi Saluran Pernapasan Atas (ISPA), Influenza, Demam Berdarah Dengue (DBD), Malaria, Pneumonia',
#   'Infeksi Saluran Pernapasan Akut (ISPA), Pneumonia, Influenza, Bronkitis Akut, Tuberkulosis (TB) Paru',
#   'Infeksi Saluran Pernapasan Atas (ISPA), Influenza, Common Cold (Pilek Biasa), Bronkitis Akut, Pneumonia',
#   'Demam Biasa (Common Fever), Infeksi Saluran Pernapasan Atas (ISPA), Demam Berdarah Dengue (DBD), Tifoid (Demam Tifoid), Malaria',
#   'Infeksi Virus (misalnya, Demam Dengue), Infeksi Bakteri (misalnya, Sepsis), Infeksi Saluran Pernapasan (misalnya, Pneumonia), Infeksi Saluran Kemih (ISK), Infeksi Sistemik Lainnya (misalnya, Malaria)',
#   'Demam Biasa (Common Fever), Infeksi Saluran Pernapasan Atas (ISPA), Demam Berdarah Dengue (DBD), Demam Tifoid (Typhoid Fever), Malaria',
#   'Demam Biasa (Common Fever), Infeksi Saluran Pernapasan Atas (ISPA), Infeksi Virus (Misalnya Demam Berdarah Dengue), Leptospirosis, Malaria',
#   'Hipertensi, Vertigo atau Gangguan Vestibular, Gangguan Gastrointestinal (Dispepsia), Hipoglikemia, Dehidrasi atau Ketidakseimbangan Elektrolit',
#   'Luka Robek Kepala (Laceratio Capitis), Trauma Kepala Ringan (Mild Traumatic Brain Injury), Peningkatan Tekanan Intrakranial (Intracranial Pressure), Fraktur Tengkorak (Skull Fracture), Hematoma Subdural atau Epidural',
#   'Luka Robek (Laceration), Infeksi Luka, Trauma Tumpul, Luka Bakar Derajat I, Luka Tusuk',
#   'Hipotensi Postural, Gangguan Kardiovaskular, Dehidrasi, Gangguan Neurologis, Hipoglikemia',
#   'Benign Paroxysmal Positional Vertigo (BPPV), Vertigo Sentral, Hipotensi Ortostatik, Migrain Vestibular, Trauma Kepala Ringan',
#   'Vulnus Excoriasi (Luka Lecet)',
#   'Luka Bakar Derajat I, Luka Bakar Deep Partial Thickness (Derajat IIb), Luka Lecet (Abrasi), Luka Robek (Laserasi), Luka Tembus (Penetrasi)',
#   'Demam Biasa, Demam Berdarah Dengue (DBD), Demam Tifoid, Leptospirosis, Infeksi Saluran Pernapasan Atas (ISPA)',
#   'Demam Biasa (Common Fever), Infeksi Saluran Pernapasan Atas (ISPA), Asthma dengan Infeksi Pernapasan, Pneumonia, Sinusitis',
#   'Gastroenteritis Akut (GE), Demam Tifoid, Infeksi Saluran Pernapasan Akut (ISPA), Demam Biasa (Viral Fever), Asthma dengan Infeksi Sekunder',
#   'Infeksi Saluran Pernapasan Atas (ISPA), Influenza, Demam Berdarah Dengue (DBD), Demam Tifoid, COVID-19',
#   'Infeksi Saluran Pernapasan Atas (ISPA), Influenza, Demam Berdarah Dengue (DBD), Faringitis, Tonsilitis',
#   'Demam Biasa (Common Cold), Infeksi Saluran Pernapasan Atas (ISPA), Influenza, Pneumonia, Asthma',
#   'Dispepsia, Gastroesophageal Reflux Disease (GERD), Ulkus Peptikum, Pankreatitis, Serangan Jantung (Infark Miokard)',
#   'Dispepsia, Gastritis, Ulkus Peptikum, Refluks Asam (GERD), Pankreatitis Akut',
#   'Gastroesophageal Reflux Disease (GERD), Dispepsia, Hipertensi dengan Komplikasi Gastrointestinal, Gastritis, Angina Pektoris',
#   'Dispepsia, Gastritis, Ulkus Peptikum, Pankreatitis Akut, Kolesistitis Akut',
#   'Eksaserbasi Asma (Serangan Asma Akut), Infeksi Saluran Pernapasan Atas (ISPA), Bronkitis Akut, Pneumonia, Rinitis Alergi dengan Eksaserbasi Asma',
#   'Dispepsia, Gastroesophageal Reflux Disease (GERD), Penyakit Jantung (Angina Pektoris), Gastritis Akut, Pankreatitis Akut',
#   'Dispepsia, Asthma, Gastroesophageal Reflux Disease (GERD), Penyakit Paru Obstruktif Kronis (PPOK), Gangguan Kardiovaskular',
#   'Asma, Bronkitis Akut, Infeksi Saluran Napas Atas (ISPA), Pneumonia, Gagal Jantung Kongestif',
#   'Eksaserbasi Asma (Serangan Asma Akut), Infeksi Saluran Pernapasan Akut (ISPA), Bronkitis Akut, Pneumonia, Gastroesophageal Reflux Disease (GERD)'],
#  'Deepseek non RAG': ['Malaria, Infeksi Saluran Kemih (ISK) atau Pielonefritis, Demam Tifoid (Tipes), Infeksi Virus (Dengue, Influenza, dll.), Sepsis atau Infeksi Bakteri Lain',
#   'Gastroenteritis Akut, Keracunan Makanan, Kolera, Irritable Bowel Syndrome (IBS) akut, Penyebab Non-Infeksi: efek samping obat, intoleransi laktosa',
#   'Demam Berdarah Dengue (DBD) / Dengue Fever, Chikungunya, Campak (Measles), Rubella (Campak Jerman), Infeksi Virus Lain: Zika, Roseola (HHV-6)',
#   'Erisipelas (Infeksi Bakteri pada Kulit dan Jaringan Subkutan), Selulitis dengan Limfangitis, Herpes Zoster (Nyeri Sebelum Ruam Muncul), Artritis Septik (Infeksi Sendi Bahu), Penyakit Autoimun (Contoh: Dermatomiositis)',
#   'Infark Miokard Akut (Serangan Jantung), Angina Pektoris Tidak Stabil, Emboli Paru, Diseksi Aorta, Penyakit Non-Jantung: GERD, Costochondritis',
#   ' Asma Akut Eksaserbasi,  PPOK Eksaserbasi Akut, Bronkitis Akut, Pneumonia, Emboli Paru (Jika Ada Faktor Risiko)',
#   'Infeksi Saluran Pernapasan Akut (ISPA) dengan Bronkitis Akut, PPOK Eksaserbasi (Jika Ada Riwayat Merokok/Paparan Polusi), Gagal Jantung Kongestif (Harus Dipertimbangkan!), Diabetes Melitus dengan Infeksi Sekunder, Sinusitis dengan Post-Nasal Drip',
#   'Asma (Tipe Non-Batuk), Pneumonia Atipik (Misal: Mycoplasma/Chlamydia), Emboli Paru, Gagal Jantung Awal, Anemia Berat, Pneumotoraks',
#   'Gastroenteritis Akut dengan Refluks Asam/GERD, Pneumonia dengan Gejala Gastrointestinal, COVID-19 atau Infeksi Virus Lain, Kolesistitis (Radang Empedu) atau Pankreatitis Akut, Gastritis Akut atau Ulkus Peptikum',
#   'Gastritis Akut, GERD (Refluks Asam Lambung), Ulkus Peptikum (Tukak Lambung/Usus 12 Jari), Kolesistitis (Radang Empedu) atau Kolik Bilier, Pankreatitis Akut',
#   'Gastroenteritis Akut Berat dengan Dehidrasi, Krisis Hipertensi Sekunder (TD 180/89 mmHg), Pankreatitis Akut, Obstruksi Usus Parsial, Kolesistitis Akut',
#   'Batu Ureter (Urolitiasis), Pielonefritis Akut (Tanpa Demam), Nyeri Otot atau Saraf',
#   'Apendisitis Akut dengan Perforasi, Obstruksi Usus, Peritonitis, Kolesistitis Akut, Pankreatitis Akut, Divertikulitis Akut',
#   'Ileus Obstruktif Parsial, Gastroparesis, Ulkus Peptikum dengan Stenosis Pilorus, Konstipasi Berat',
#   'Kolik Ureter (Batu Saluran Kemih), Disfungsi Usus (IBS Tipe Kram atau Obstruksi Parsial), Nyeri Panggul Kronis (Endometriosis/Adenomiosis), Neuralgia Saraf Perifer (Nyeri Neuropatik)',
#   'Gastroenteritis Akut Viral, Flu Lambung (Viral Gastroenteritis + ISPA), Pneumonia Atipik (Terutama pada Anak), GERD dengan Iritasi Tenggorokan, COVID-19 dengan Gejala GI',
#   'Influenza/ISPA Viral, COVID-19, Infeksi Bakteri Sekunder (Sinusitis, Otitis Media), Dengue Fever',
#   'Infeksi Saluran Pernapasan Akut (ISPA) Bakterial, Influenza, COVID-19, Tuberkulosis (TB) Paru, Dengue Fever',
#   'Influenza (Flu), Common Cold (Selesma), COVID-19, Infeksi Bakteri Sekunder (Jika Gejala Memburuk)',
#   'Influenza (Flu), COVID-19, Demam Berdarah Dengue (DBD) - Fase Awal, Infeksi Bakteri (Pneumonia/Tifoid), Infeksi Saluran Kemih (ISK)',
#   'Infeksi Virus (Influenza/COVID-19/Dengue), Infeksi Bakteri (Pneumonia/Tifoid/ISK)',
#   'Influenza (Flu Musiman), COVID-19 (Varian Terkini), Demam Berdarah Dengue (DBD - Fase Awal)',
#   'Infeksi Virus Akut (Influenza/COVID-19/Dengue), Dehidrasi dengan Demam, Anemia dengan Infeksi Bersamaan, Hipertiroidisme dengan Krisis Tirotoksikosis',
#   'Hipotensi Ortostatik atau Presinkop, Vertigo Vestibular (BPPV/Labirinitis), Hipertensi Emergensi dengan Ensefalopati, Gangguan Elektrolit (Hiponatremia/Hipokalemia), Aritmia Jantung (Sindrom Sick Sinus, AV Blok)',
#   'Luka Robek Kepala (Scalp Laceration) dengan Trauma Kepala Ringan-Sedang, Kemungkinan Komplikasi yang Harus Disingkirkan:\nConcussion (Gegar Otak Ringan)\nFraktur tengkorak\nPerdarahan intrakranial (epidural/subdural hematoma)',
#   'Luka Robek (Laceration) pada Siku Kanan',
#   'Trauma Muskuloskeletal Ringan, Fraktur atau Dislokasi (Jika Ada Mekanisme Jatuh Keras), Concussion (Gegar Otak Ringan)',
#   'vertigo posisional paroksismal benigna (BPPV), Hipotensi ortostatik, Gangguan telinga dalam lainnya, Masalah neurologis (misalnya migrain vestibular atau stroke).',
#   'Abrasi',
#   'Luka lecet (abrasi), Luka robek (lacerasi), Luka terbuka (open wound), Luka tembus (penetrasi)',
#   'Infeksi Virus (misalnya, Influenza atau Dengue), Infeksi Bakteri (misalnya, Tifoid atau Leptospirosis), Malaria, Penyakit Autoimun atau Inflamasi, Dehidrasi atau Kelelahan Ekstrem',
#   'infeksi saluran pernapasan atas (ISPA)',
#   'Infeksi Virus (Flu atau Gastroenteritis Virus), Infeksi Bakteri, Infeksi Campuran',
#   'Common Cold (ISPA Virus), Influenza (Flu), Infeksi Saluran Pernapasan Akut (ISPA) Lainnya',
#   'Influenza (Flu), COVID-19, Faringitis Akut, Mononukleosis Infeksiosa (EBV/CMV), Common Cold (Selesma)',
#   'Bronkitis Akut (Viral),  Influenza (Flu) dengan Komplikasi Saluran Napas Bawah, Sinusitis Akut (Jika Pilek Berkepanjangan & Ada Nyeri Wajah), Pneumonia (Jika Ada Tanda Infeksi Paru), COVID-19 (Harus Dipertimbangkan)',
#   'GERD (Gastroesophageal Reflux Disease), hipertensi',
#   'Gastritis atau Tukak Lambung (Ulkus Peptikum), Refluks Asam (GERD), Pankreatitis, Serangan Jantung (Infark Miokard), Keracunan Makanan atau Infeksi Gastrointestinal, Kolesistitis (Radang Kantung Empedu)',
#   'gastroesophageal reflux disease (GERD), angina pectoris',
#   'Ulkus Peptik (Tukak Lambung atau Usus), Pankreatitis Akut, Kolesistitis (Radang Kantung Empedu), Obstruksi Usus, Gangguan Elektrolit atau Dehidrasi, Gastroenteritis Akut, Serangan Jantung (Infark Miokard)',
#   'Infeksi saluran pernapasan akut (ISPA), Bronkitis akut, Pneumonia',
#   'Gastroesophageal Reflux Disease (GERD), Ulkus Peptik, Serangan Jantung (Infark Miokard), Pankreatitis Akut, Kolesistitis Akut',
#   'Gastroesophageal Reflux Disease (GERD), Gastritis atau Tukak Lambung, Penyakit Jantung (Misalnya, Angina atau Serangan Jantung), Gangguan Pankreas atau Empedu, Infeksi atau Peradangan Lainnya, Gangguan Kecemasan atau Panik',
#   'Gagal Jantung Kongestif (Heart Failure), Infeksi Saluran Pernapasan (ISPA), Asma atau Penyakit Paru Obstruktif Kronik (PPOK)',
#   'eksaserbasi asma']}

# %%
eval_df = df[['No', 'Question']]
checkpoint = "../bleurt/bleurt/test_checkpoint"
scorer = bleurt_score_module.BleurtScorer(checkpoint)

for k, v in answer_lists.items():
    if k == 'Dr': continue

    print(f'k={k}')
    # BERT Score
    P, R, F1 = bert_score_fn(refs=answer_lists['Dr'], cands=answer_lists[k], lang='en', verbose=True)
    eval_df[f'{k}_P'] = P.tolist()
    eval_df[f'{k}_R'] = R.tolist()
    eval_df[f'{k}_F1'] = F1.tolist()

    # BLEURT Score
    scores = scorer.score(references=answer_lists['Dr'], candidates=answer_lists[k])
    eval_df[f'{k}_BLEURT'] = scores
# Out:
# INFO:tensorflow:Reading checkpoint ../bleurt/bleurt/test_checkpoint.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint dbleurt_tiny
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:dbleurt_tiny
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# WARNING:tensorflow:From d:\Research_Assistant\evaluation_radiology_gpt\test-env\Lib\site-packages\bleurt\lib\bert_tokenization.py:94: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.
# k=Claude
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 2/2 [00:11<00:00,  5.59s/it]
# computing greedy matching.
# 100%|██████████| 1/1 [00:00<00:00, 55.56it/s]
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_P'] = P.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_R'] = R.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_F1'] = F1.tolist()
# done in 11.20 seconds, 4.02 sentences/sec
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_BLEURT'] = scores
# k=Qwen
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 2/2 [00:10<00:00,  5.44s/it]
# computing greedy matching.
# 100%|██████████| 1/1 [00:00<00:00, 64.37it/s]
# done in 10.91 seconds, 4.12 sentences/sec
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_P'] = P.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_R'] = R.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_F1'] = F1.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_BLEURT'] = scores
# k=GPT
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 2/2 [00:09<00:00,  4.54s/it]
# computing greedy matching.
# 100%|██████████| 1/1 [00:00<00:00, 99.98it/s]
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_P'] = P.tolist()
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12928\1208546096.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eval_df[f'{k}_R'] = R.tolist()
# done in 9.09 seconds, 4.95 sentences/sec
# k=Deepseek RAG
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 2/2 [00:12<00:00,  6.09s/it]
# computing greedy matching.
# 100%|██████████| 1/1 [00:00<00:00, 83.14it/s]
# done in 12.21 seconds, 3.69 sentences/sec
# k=Deepseek non RAG
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 2/2 [00:14<00:00,  7.21s/it]
# computing greedy matching.
# 100%|██████████| 1/1 [00:00<00:00, 64.46it/s]
# done in 14.45 seconds, 3.12 sentences/sec

# %%
eval_df.describe()
# Out:
#               No   Claude_P   Claude_R  Claude_F1  Claude_BLEURT     Qwen_P  \
# count  45.000000  45.000000  45.000000  45.000000      45.000000  45.000000
# mean   23.000000   0.856848   0.908259   0.881591      -0.317442   0.808401
# std    13.133926   0.043894   0.025749   0.034132       0.309819   0.035417
# min     1.000000   0.748749   0.846060   0.796143      -1.220764   0.730712
# 25%    12.000000   0.832780   0.899328   0.868169      -0.492355   0.789274
# 50%    23.000000   0.865030   0.912973   0.884388      -0.221711   0.809001
# 75%    34.000000   0.883578   0.927474   0.905364      -0.088721   0.830963
# max    45.000000   0.944525   0.959008   0.951711       0.135739   0.879325
#
#           Qwen_R    Qwen_F1  Qwen_BLEURT      GPT_P  ...     GPT_F1  \
# count  45.000000  45.000000    45.000000  45.000000  ...  45.000000
# mean    0.835514   0.821410    -0.723486   0.816437  ...   0.835200
# std     0.040780   0.034499     0.407063   0.039830  ...   0.036766
# min     0.756705   0.757629    -1.682293   0.708608  ...   0.751015
# 25%     0.808681   0.801019    -1.029331   0.788427  ...   0.806599
# 50%     0.832467   0.826844    -0.692648   0.824803  ...   0.838904
# 75%     0.867910   0.842796    -0.492997   0.843696  ...   0.861037
# max     0.922244   0.899288    -0.001615   0.883068  ...   0.899019
#
#        GPT_BLEURT  Deepseek RAG_P  Deepseek RAG_R  Deepseek RAG_F1  \
# count   45.000000       45.000000       45.000000        45.000000
# mean    -0.601470        0.808853        0.854358         0.830666
# std      0.373857        0.039609        0.031684         0.032376
# min     -1.647727        0.719105        0.782974         0.763067
# 25%     -0.798630        0.780109        0.834833         0.807060
# 50%     -0.506042        0.811930        0.854831         0.828900
# 75%     -0.320304        0.841838        0.877455         0.855788
# max     -0.035894        0.907079        0.914508         0.893472
#
#        Deepseek RAG_BLEURT  Deepseek non RAG_P  Deepseek non RAG_R  \
# count            45.000000           45.000000           45.000000
# mean             -0.626380            0.793207            0.830242
# std               0.382500            0.040971            0.026859
# min              -1.478109            0.723283            0.767381
# 25%              -0.960766            0.766470            0.815271
# 50%              -0.535418            0.789994            0.832200
# 75%              -0.299144            0.814962            0.848682
# max               0.042698            0.912450            0.885356
#
#        Deepseek non RAG_F1  Deepseek non RAG_BLEURT
# count            45.000000                45.000000
# mean              0.810962                -0.856161
# std               0.030747                 0.363157
# min               0.751236                -1.490810
# 25%               0.790469                -1.190375
# 50%               0.807447                -0.869014
# 75%               0.830417                -0.548639
# max               0.898699                -0.212206
#
# [8 rows x 21 columns]

# %%
# Distribution of BLEURT 
import matplotlib.pyplot as plt

bleurt_columns = [col for col in eval_df.columns if col.endswith('_BLEURT')]
eval_df[bleurt_columns].hist(bins=20, figsize=(15, 10), grid=False, layout=(-1, 2))

plt.suptitle('Distribution of BLEURT Scores', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
plt.show()
