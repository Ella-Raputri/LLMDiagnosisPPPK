# %%
import pandas as pd
import numpy as np
import json
import os
import re
import warnings
import openai
from dotenv import load_dotenv
warnings.filterwarnings('ignore')
from tqdm import tqdm

# %%
load_dotenv()
client = openai.OpenAI(api_key=os.environ.get("OPENAI_API_KEY2"))

# %%
df = pd.read_csv('../cleaning_before_eval/ready_to_eval.csv')
df.head()
# Out:
#     No                                           Question  \
# 0  1.0  Pasien mengalami demam pada waktu malam. Sebel...
# 1  2.0  Pasien mengalami buang air besar cair lebih da...
# 2  3.0  Pasien datang dengan keluhan demam selama 6 ha...
# 3  4.0  Pasien menderita demam disertai munculnya brun...
# 4  5.0  Pasien nyeri dada sejak 4 jam lalu seperti ter...
#
#                                            Dr Answer  \
# 0        Demam Tifoid 70%, Demam Berdarah Dengue 30%
# 1  Gastroenteritis (GE) Akut 70%, Intoleransi Lak...
# 2                                            DBD 80%
# 3  Infeksi Bakteri/Virus (Sistemik) 50%, Infeksi ...
# 4  Angina Pekrotis 80%, Infark Miokard Akut (Sera...
#
#                                        Claude Answer  \
# 0  Demam Tifoid, Leptospirosis, Demam Berdarah De...
# 1  Gastroenteritis (GE) Akut, Disentri, Infeksi E...
# 2  Demam Tifoid, Malaria, DBD, Leptospirosis, Inf...
# 3  DBD, Infeksi Bakteri/Virus (Sistemik), Infeksi...
# 4  Angina Pekrotis, Infark Miokard Akut (Serangan...
#
#                                          Qwen Answer  \
# 0  Demam Biasa, Dispepsia, Asma, Infeksi Saluran ...
# 1  Diare Akut, Gastroenteritis, Dispepsia, Infeks...
# 2  Demam Biasa, Dispepsia, Asma, Demam Dengue, Lu...
# 3  Demam Biasa, Dispepsia, Asma, Infeksi Lokal, A...
# 4  Infark Miokard Akut (Serangan Jantung), Dispep...
#
#                                           GPT Answer  \
# 0  Demam Biasa, Demam Tifoid, Demam Berdarah Deng...
# 1  Gastroenteritis Akut, Infeksi Escherichia coli...
# 2  Demam Berdarah Dengue, Demam Tifoid, Malaria, ...
# 3  Infeksi Kulit (Dermatitis atau Selulitis), Kej...
# 4  Angina Pekrotis, Infark Miokard, Penyakit Musk...
#
#                                  Deepseek RAG Answer  \
# 0  Demam Tifoid (Typhoid Fever), Malaria, Leptosp...
# 1  Gastroenteritis Akut, Keracunan Makanan, Infek...
# 2  Demam Berdarah Dengue (DBD), Demam Tifoid, Lep...
# 3  Infeksi Bakteri (Selulitis), Reaksi Alergi (De...
# 4  Angina Pectoris (Kardiovaskular), Infark Mioka...
#
#                              Deepseek non RAG Answer  \
# 0  Malaria, Infeksi Saluran Kemih (ISK) atau Piel...
# 1  Gastroenteritis Akut, Keracunan Makanan, Koler...
# 2  Demam Berdarah Dengue (DBD) / Dengue Fever, Ch...
# 3  Erisipelas (Infeksi Bakteri pada Kulit dan Jar...
# 4  Infark Miokard Akut (Serangan Jantung), Angina...
#
#                                   Claude Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, saya akan...
# 1  Berdasarkan informasi klinis yang diberikan, s...
# 2  Berdasarkan informasi yang diberikan, saya aka...
# 3  Berdasarkan informasi klinis yang diberikan, s...
# 4  Berdasarkan informasi yang diberikan dalam kon...
#
#                                     Qwen Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, yaitu dem...
# 1  Berdasarkan gejala yang disampaikan, yaitu bua...
# 2  Berdasarkan gejala yang disampaikan, yaitu dem...
# 3  Berdasarkan gejala yang disampaikan, yaitu dem...
# 4  Berdasarkan gejala yang disampaikan, yaitu nye...
#
#                                      GPT Full Answer  \
# 0  Berdasarkan gejala yang disampaikan, yaitu dem...
# 1  Berdasarkan informasi yang diberikan, pasien m...
# 2  Berdasarkan keluhan yang disampaikan oleh pasi...
# 3  Berdasarkan informasi yang diberikan, pasien m...
# 4  Berdasarkan informasi yang diberikan, pasien m...
#
#                             Deepseek RAG Full Answer  \
# 0  Berdasarkan gejala yang dialami pasien, yaitu ...
# 1  Berdasarkan informasi yang diberikan, pasien m...
# 2  Berdasarkan keluhan pasien yang meliputi demam...
# 3  ### Analisis Gejala dan Kemungkinan Diagnosis\...
# 4  ### Analisis Gejala\r\n\r\nPasien mengeluhkan ...
#
#                         Deepseek non RAG Full Answer
# 0  Berdasarkan gejala yang Anda sebutkan—demam pa...
# 1  Berdasarkan gejala yang Anda deskripsikan—diar...
# 2  Berdasarkan gejala yang Anda sebutkan—demam ≥6...
# 3  Berdasarkan gejala dan temuan pemeriksaan yang...
# 4  Berdasarkan gejala nyeri dada seperti terhimpi...

# %%
with open('kamus.json', 'r') as file:
    SYNONYM_MAP = json.load(file)
    
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    for abbr, canonical in SYNONYM_MAP.items():
        abb = abbr.lower()
        canon = canonical.lower()

        if (text == canon): break
        pattern = rf'\b{re.escape(abb)}\b'
        if re.search(pattern, text):
            text = re.sub(pattern, canon, text)
            break
        
    return text

# %%
import time

def llm_judge_answer(question, candidate_answer:str, gt_answers:str, model_name="gpt-3.5-turbo", max_retries=3):
    for attempt in range(max_retries):
        try:
            if attempt > 0:
                delay = 2 ** attempt  
                print(f"Retrying after {delay} seconds...")
                time.sleep(delay)
            
            normalized_candidate = normalize_text(candidate_answer)
            ground_truth_text = normalize_text(gt_answers)

            prompt = f"""
            You are a medical expert evaluating diagnosis answers. Please judge whether the candidate answer is appropriate, based on the ground truth diagnoses.

            Question: {question}
            Ground Truth Answers: {ground_truth_text}
            Candidate Answer: {normalized_candidate}

            Evaluation Instructions:
            1. Carefully read all the ground truth diagnoses and note the probability (%) associated with each. These percentages represent subjective probabilities assigned by a human doctor.
            2. Read the candidate answer(s). For each, determine whether it is:
            a. Correct and matches one of the ground truth diagnoses  
            b. Partially correct or related (e.g., a broader category, symptom-level, or similar condition)  
            c. Incorrect or unrelated

            3. If the candidate answer matches any ground truth diagnosis exactly, score it only based on the match and the probability assigned to that diagnosis. 
            - A match with a high-probability diagnosis (e.g., 70%) should result in a high score (close to 1).
            - A match with a low-probability diagnosis (e.g., 10%) should still be credited, but with a lower score.

            4. If the candidate answer is only partially related (e.g., a plausible but incorrect differential diagnosis), score accordingly with a moderate value.

            5. If the answer is incorrect or unrelated, assign a low score close to 0.

            6. Very important: Do NOT penalize the candidate for not mentioning all ground truth diagnoses.  
            If the candidate matches the top diagnosis (the one with the highest percentage), give it a high score (e.g., 0.9 to 1.0), even if other diagnoses are not mentioned.  
            Only score lower if the top diagnosis is not mentioned or the answer is incorrect.
            You are only evaluating the correctness and relevance of the candidate diagnosis, not how exhaustive it is.

            7. Important: If the candidate includes the top diagnosis (the one with the highest percentage), and also includes unrelated or incorrect diagnoses, still assign a high score. 
            Do not penalize the answer just because it includes extra incorrect diagnoses, as long as the top correct one is clearly present.

            Examples:
            - Candidate 1: 'Demam tifoid' → GT: 'Demam Tifoid 70%, Demam DBD 30%' → Score above 0.9 (correct match to top GT)
            - Candidate 2: 'Demam tifoid, demam biasa' → GT: same → Score above 0.8, lower than candidate 1 (top GT match + noise)
            - Candidate 3: 'Demam DBD, demam biasa' → GT: same → Score above 0.6, lower than candidate 2 (match to lower GT + noise)
            - Candidate 4: 'Demam biasa' → GT: same → Score: 0.2 (unrelated)

            Respond with a JSON object in the following format:
            {{
            "score": <float score from 0 to 1>,
            "reasoning": "<brief explanation of your judgment>",
            "category": "<correct|partial|incorrect>"
            }}

            Response:
            """

            response = client.chat.completions.create(
                model=model_name,
                messages=[
                    {"role": "system", "content": "You are a medical expert evaluating diagnosis accuracy."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.1,
                max_tokens=200
            )

            response_text = response.choices[0].message.content
            # print(response_text)
            try:
                start_idx = response_text.find('{')
                end_idx = response_text.rfind('}') + 1
                json_str = response_text[start_idx:end_idx]
                
                result = json.loads(json_str)
                if 'score' in result and 'reasoning' in result and 'category' in result:
                    return result
                else:
                    raise ValueError("Invalid response structure")
                    
            except Exception as parse_error:
                print(f"Parse error on attempt {attempt + 1}: {parse_error}")
                if attempt == max_retries - 1:
                    return {
                        "score": 0.5,
                        "reasoning": "Could not parse LLM response after multiple attempts",
                        "category": "partial"
                    }
                continue
                
        except Exception as e:
            print(f"API error on attempt {attempt + 1}: {e}")
            if "insufficient_quota" in str(e) or "quota" in str(e).lower():
                print("⚠️  OpenAI API quota exceeded. Please check your billing.")
                return {
                    "score": 0.0,
                    "reasoning": "API quota exceeded",
                    "category": "error"
                }
            elif attempt == max_retries - 1:
                return {
                    "score": 0.0,
                    "reasoning": f"API error after {max_retries} attempts: {str(e)}",
                    "category": "error"
                }
            continue

    return {
        "score": 0.0,
        "reasoning": "Unknown error occurred",
        "category": "error"
    }

# %%
sample_question = "Pasien mengalami demam pada waktu malam"
sample_candidate = "Demam berdarah, demam tifoid, demam biasa"
sample_gt = "Demam Tifoid 70%, Demam Berdarah Dengue 30%"

# test_result = llm_judge_answer(sample_question, sample_candidate, sample_gt)
# print(f"Test Result 3.5: {test_result}")
test_result = llm_judge_answer(sample_question, sample_candidate, sample_gt, model_name='gpt-4-turbo')
print(f"Test Result 4: {test_result}")
# Out:
# Test Result 4: {'score': 0.8, 'reasoning': "The candidate answer includes 'demam berdarah dengue' and 'demam tifoid', both of which are present in the ground truth diagnoses. However, it also includes 'demam biasa', which is not specified in the ground truth. This additional diagnosis is more general and not directly related to the specific conditions listed in the ground truth. Therefore, while the answer correctly identifies two specific conditions, the inclusion of a less relevant diagnosis slightly lowers the score.", 'category': 'partial'}

# %%
sample_question = "Pasien mengalami demam pada waktu malam"
sample_candidate = "Demam tifoid, demam biasa"
sample_gt = "Demam Tifoid 70%, Demam Berdarah Dengue 30%"

# test_result = llm_judge_answer(sample_question, sample_candidate, sample_gt)
# print(f"Test Result 3.5: {test_result}")
test_result = llm_judge_answer(sample_question, sample_candidate, sample_gt, model_name='gpt-4-turbo')
print(f"Test Result 4: {test_result}")
# Out:
# Test Result 4: {'score': 0.8, 'reasoning': "The candidate answer includes 'demam tifoid' which is a correct match to the ground truth diagnoses. However, it also includes 'common fever' which is not mentioned in the ground truth diagnoses, hence it is considered as noise.", 'category': 'partial'}

# %%
def find_all_round_judgement(candidate_answers, question, gt_answers, model_name):
    if not candidate_answers or not gt_answers:
        return None, 0.0, {}
        
    cands = ",".join(candidate_answers)
    all_judge = llm_judge_answer(question, cands, gt_answers, model_name)
    
    return all_judge

# %%
def process_row(row):
    print(f"Processing row {row.name}...")
    # truth_list = [item.strip() for item in row['Dr Answer'].split(',')]
    model_cols = {
        'Claude Answer': 'LLM_JUDGE_Claude',
        'Qwen Answer': 'LLM_JUDGE_Qwen',
        'GPT Answer': 'LLM_JUDGE_GPT',
        'Deepseek RAG Answer': 'LLM_JUDGE_Deepseek_RAG',
        'Deepseek non RAG Answer': 'LLM_JUDGE_Deepseek_nonRAG'
    }
    # gpt-3.5-turbo
    # 'gpt-4-0613'
    for col_name, result_col in tqdm(model_cols.items(), desc='Processing models'):
        model_list = [item.strip() for item in row[col_name].split(',')]
        result = find_all_round_judgement(model_list, row['Question'], row['Dr Answer'], model_name='gpt-4-turbo')

        row[f'{result_col}_score'] = result.get('score', 0.0)
        row[f'{result_col}_reasoning'] = result.get('reasoning', 0.0)
        row[f'{result_col}_category'] = result.get('category', 0.0)
    
    return row

# %%
df_new = df.copy()
df_new
# Out:
#       No                                           Question  \
# 0    1.0  Pasien mengalami demam pada waktu malam. Sebel...
# 1    2.0  Pasien mengalami buang air besar cair lebih da...
# 2    3.0  Pasien datang dengan keluhan demam selama 6 ha...
# 3    4.0  Pasien menderita demam disertai munculnya brun...
# 4    5.0  Pasien nyeri dada sejak 4 jam lalu seperti ter...
# 5    6.0  Pasien mengalami sesak nafas sejak siang. #Has...
# 6    7.0  Pasien mengalami sesak napas sejak sehari lalu...
# 7    8.0  Pasien mengalami sesak nafas sekitar 3 hari, t...
# 8    9.0  Pasien nyeri ulu hati/perut bagian atas sejak ...
# 9   10.0  Pasien merasa nyeri di ulu hati sampai terasa ...
# 10  11.0  Pasien mengalami buang air besar cair 5 kali l...
# 11  12.0  Pasien nyeri pinggang kanan sejak 6 jam lalu, ...
# 12  13.0  Pasien mengalami nyeri perut sejak sehari lalu...
# 13  14.0  Pasien mengalami nyeri perut, mulas, mual, mun...
# 14  15.0  Pasien mengalami nyeri hebat di perut bawah, d...
# 15  16.0  Pasien muntah-muntah sejak 3 hari lalu setiap ...
# 16  17.0  Pasien mengalami demam, menggigil, sulit tidur...
# 17  18.0  Pasien demam tinggi hari ke 3, batuk berdahak,...
# 24  Trauma kepala ringan = Cedera Kepala Ringan (C...
# 25  Luka bakar superfisial (derajat I), Luka Terbu...
# 26                              Post Trauma , -, -, -
# 27  CKR disebabkan oleh Vertigo, Luka Terbuka/Robe...
# 28  Definisi Vulnus Excoriasi, Luka Lecet (Vulnus ...
# 29  Luka Bakar /Burn Injury (Derajat III) , Luka B...
# 30  Demam Biasa (Common Fever), Infeksi Sistemik, ...
# 31  Demam Biasa (Common Cold), Influenza, Demam Be...
# 32  Gastroenteritis(GE), Influenza, Demam Biasa (I...
# 33  Demam Biasa (Viral), Demam dengue, Infeksi sal...
# 34  Demam biasa, Influenza, Infeksi saluran pernap...
# 35  Demam tifoid, DBD, Infeksi saluran pernapasan ...
# 36  Dispepsia, Gastritis , Refluks Asam Lambung (G...
# 37  Dispepsia, Gastritis akut, Reflux Gastroesofag...
# 38  Dispepsia, Gastritis , Gastroesofageal reflux ...
# 39  Dispepsia , Gastritis akut, Appendisitis, Peri...
# 40  Status Asmatikus (Asma Akut Berat), Asma Bronk...
# 41  Dispepsia, Penyakit Kardiovaskular, Gastritis ...
# 42  Gangguan Saluran Pencernaan, Dispepsia , Asma,...
# 43  Asma, Bronkitis Akut , Laringitis, Infeksi sal...
# 44  Status Asmatikus (Asma Akut Berat), Asma Eksas...
#
#                                           Qwen Answer  \
# 0   Demam Biasa, Dispepsia, Asma, Infeksi Saluran ...
# 1   Diare Akut, Gastroenteritis, Dispepsia, Infeks...
# 2   Demam Biasa, Dispepsia, Asma, Demam Dengue, Lu...
# 3   Demam Biasa, Dispepsia, Asma, Infeksi Lokal, A...
# 4   Infark Miokard Akut (Serangan Jantung), Dispep...
# 5   Asma, Pneumonia, Dispepsia, Demam biasa, Kardi...
# 6   Asma, Infeksi Saluran Pernapasan Atas (ISPA), ...
# 7   Asma, Dispepsia, Pneumonia, Anemia, Kardiomiopati
# 8   Dispepsia, Demam Biasa, Asma, Infeksi saluran ...
# 9   Dispepsia Fungsional, Gastritis, Reflux Asam L...
# 10  Gastroenteritis Akut, Dispepsia Fungsional, In...
# 11  Infeksi Saluran Kemih (ISK) Akut, Batuk Ginjal...
# 12  Dispepsia, Apendisitis, Demam Biasa, Asma, Obs...
# 13  Dispepsia, Obstruksi Usus, Kolitis, Penyakit C...
# 14  Dispepsia Fungsional, Endometriosis, Salpingit...
# 15  Dispepsia Fungsional, Demam Biasa, Asma, Infek...
# 16  Demam Biasa, Pneumonia, Influenza, Asma, Dispe...
# 17  Demam Biasa, Asma, Dispepsia, Infeksi Saluran ...
# 18  Demam Biasa, Asma, Dispepsia, Infeksi Saluran ...
# 19  Demam Biasa, Asma, Dispepsia, Infeksi Saluran ...
# 20  Demam Biasa, Pneumonia, Infeksi Saluran Kemih ...
# 21  Demam biasa, Influenza, Dispepsia, Asma, Infek...
# 22  Demam Biasa, Dispepsia, Asma, Infeksi Saluran ...
# 23  Hipertensi Akut, Dispepsia, Demam Biasa, Asma,...
# 24  Luka Robek (Laceration), Kepala Cedera Ringan ...
# 25  Luka Robek (Laceration), Nyeri Akibat Luka, In...
# 12  " Berdasarkan gejala yang dialami oleh pasien,...
# 13  "Pasien mengalami gejala yang meliputi nyeri p...
# 14  "Berdasarkan gejala dan hasil pemeriksaan yang...
# 15  "Berdasarkan gejala dan hasil pemeriksaan yang...
# 16  "Pasien mengalami gejala demam, menggigil, sul...
# 17  "ini adalah jawaban yang panjang, terstruktur,...
# 18  " Berdasarkan gejala yang dialami oleh pasien,...
# 19  "Berdasarkan gejala yang dialami pasien, yaitu...
# 20  "### Analisis Gejala dan Tanda Klinis\r\n\r\nB...
# 21  "Berdasarkan gejala yang dialami pasien, yaitu...
# 22  "Berdasarkan gejala yang dialami pasien, yaitu...
# 23  "Berdasarkan informasi yang diberikan, pasien ...
# 24  "Berdasarkan informasi yang diberikan, pasien ...
# 25  "### Analisis Gejala dan Kemungkinan Diagnosis...
# 26  "Untuk menjawab pertanyaan ini, kita perlu mem...
# 27  "Berdasarkan gejala yang dialami pasien, yaitu...
# 28  "Berdasarkan informasi yang diberikan, pasien ...
# 29  "Berdasarkan informasi yang diberikan, pasien ...
# 30  "Berdasarkan gejala yang dialami pasien, yaitu...
# 31  "Berdasarkan informasi yang diberikan, pasien ...
# 32  "Berdasarkan gejala yang dialami pasien, berik...
# 33  " Berdasarkan informasi yang diberikan, pasien...
# 34  "Berdasarkan gejala yang dialami oleh pasien, ...
# 35  "Berdasarkan gejala yang dialami pasien, yaitu...
# 36  "Berdasarkan gejala yang dialami pasien, yaitu...
# 37  "Berdasarkan gejala yang dialami pasien, yaitu...
# 38  "Berdasarkan gejala yang dialami pasien, yaitu...
# 39  "Pasien yang mengalami nyeri hebat di perut ba...
# 40  "Pasien dengan gejala sesak napas, lemas, batu...
# 41  "### Analisis Gejala\r\n\r\nPasien mengeluh ny...
# 42  "### Analisis Gejala Pasien\r\n\r\nPasien meng...
# 43  "Berdasarkan gejala yang dialami pasien, yaitu...
# 44  "Berdasarkan informasi yang diberikan, pasien ...
#
#                          Deepseek non RAG Full Answer
# 0   Berdasarkan gejala yang Anda sebutkan—demam pa...
# 1   Berdasarkan gejala yang Anda deskripsikan—diar...
# 2   Berdasarkan gejala yang Anda sebutkan—demam ≥6...
# 3   Berdasarkan gejala dan temuan pemeriksaan yang...
# 4   Berdasarkan gejala nyeri dada seperti terhimpi...
# 5   Berdasarkan gejala sesak napas disertai wheezi...
# 6   Berdasarkan gejala dan hasil pemeriksaan, pasi...
# 7   Berdasarkan gejala sesak napas selama 3 hari t...
# 8   Berdasarkan gejala nyeri ulu hati, mual-muntah...
# 9   Berdasarkan gejala nyeri ulu hati (epigastrium...
# 10  Berdasarkan gejala dan temuan klinis yang Anda...
# 11  Berdasarkan gejala nyeri pinggang kanan akut (...
# 12  Berdasarkan gejala nyeri perut progresif yang ...
# 13  Berdasarkan gejala dan hasil pemeriksaan, pasi...
# 14  Berdasarkan gejala dan hasil pemeriksaan, pasi...
# 15  Berdasarkan gejala dan hasil pemeriksaan, pasi...
# 16  Berdasarkan gejala dan hasil pemeriksaan, pasi...
# 17  Berdasarkan gejala demam tinggi (>38°C) selama...
# 18  Berdasarkan gejala demam tinggi, batuk, dan pi...
# 19  Berdasarkan gejala demam tinggi persisten (tid...
# 20  Berdasarkan gejala demam tinggi (39,2°C) yang ...
# 21  Berdasarkan gejala demam tinggi + badan linu +...
# 22  Berdasarkan gejala demam, lemas, pusing, dan h...
# 23  Berdasarkan gejala pingsan yang diikuti pusing...
# 24  Berdasarkan informasi yang diberikan, pasien m...
# 25  Berdasarkan informasi yang diberikan, pasien m...
# 26  Berdasarkan informasi yang diberikan, pasien m...
# 27  Pasien yang mengalami gejala seperti kepala te...
# 28  "Luka lecet akibat terjatuh biasanya diidentif...
# 29  "Pasien yang terkena petasan di tangan kiri ke...
# 30  "Terdapat beberapa kemungkinan penyebab gejala...
# 31  "Pasien yang mengalami demam selama 2 hari dis...
# 32  "Berdasarkan gejala yang Anda sampaikan, pasie...
# 33  Berdasarkan gejala yang disebutkan (demam sela...
# 34  Berdasarkan gejala yang Anda sebutkan (demam, ...
# 35  Berdasarkan gejala demam tinggi selama 3 hari ...
# 36  "Berdasarkan gejala yang Anda deskripsikan, pa...
# 37  Gejala yang Anda jelaskan, seperti nyeri di ul...
# 38  "Berdasarkan gejala yang Anda jelaskan, pasien...
# 39  "Pasien yang mengalami gejala seperti nyeri he...
# 40  "Berdasarkan gejala yang dialami pasien, yaitu...
# 41  "Dari gejala yang Anda jelaskan, pasien mungki...
# 42  "Keluhan yang Anda sampaikan, yaitu nyeri ulu ...
# 43  "Berdasarkan gejala yang Anda sampaikan, pasie...
# 44  "Berdasarkan gejala yang Anda jelaskan, pasien...

# %%
df_new = df_new.apply(process_row, axis=1)
# Out:
# Processing row 0...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.78s/it]
# Processing row 1...
# Processing models: 100%|██████████| 5/5 [00:20<00:00,  4.18s/it]
# Processing row 2...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.81s/it]
# Processing row 3...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.85s/it]
# Processing row 4...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.83s/it]
# Processing row 5...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.72s/it]
# Processing row 6...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.27s/it]
# Processing row 7...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.43s/it]
# Processing row 8...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.50s/it]
# Processing row 9...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.92s/it]
# Processing row 10...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.68s/it]
# Processing row 11...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.83s/it]
# Processing row 12...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.83s/it]
# Processing row 13...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.40s/it]
# Processing row 14...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.79s/it]
# Processing row 15...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.46s/it]
# Processing row 16...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.48s/it]
# Processing row 17...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.73s/it]
# Processing row 18...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.33s/it]
# Processing row 19...
# Processing models: 100%|██████████| 5/5 [00:15<00:00,  3.11s/it]
# Processing row 20...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.77s/it]
# Processing row 21...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.25s/it]
# Processing row 22...
# Processing models: 100%|██████████| 5/5 [00:20<00:00,  4.08s/it]
# Processing row 23...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.65s/it]
# Processing row 24...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.53s/it]
# Processing row 25...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.42s/it]
# Processing row 26...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.25s/it]
# Processing row 27...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.56s/it]
# Processing row 28...
# Processing models: 100%|██████████| 5/5 [00:13<00:00,  2.71s/it]
# Processing row 29...
# Processing models: 100%|██████████| 5/5 [00:15<00:00,  3.00s/it]
# Processing row 30...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.77s/it]
# Processing row 31...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.49s/it]
# Processing row 32...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.82s/it]
# Processing row 33...
# Processing models: 100%|██████████| 5/5 [00:15<00:00,  3.13s/it]
# Processing row 34...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.60s/it]
# Processing row 35...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.48s/it]
# Processing row 36...
# Processing models:  60%|██████    | 3/5 [00:10<00:06,  3.49s/it]
# Parse error on attempt 1: Expecting value: line 1 column 1 (char 0)
# Retrying after 2 seconds...
# Processing models: 100%|██████████| 5/5 [00:25<00:00,  5.10s/it]
# Processing row 37...
# Processing models: 100%|██████████| 5/5 [00:19<00:00,  3.87s/it]
# Processing row 38...
# Processing models: 100%|██████████| 5/5 [00:21<00:00,  4.38s/it]
# Processing row 39...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.26s/it]
# Processing row 40...
# Processing models: 100%|██████████| 5/5 [00:17<00:00,  3.54s/it]
# Processing row 41...
# Processing models: 100%|██████████| 5/5 [00:21<00:00,  4.36s/it]
# Processing row 42...
# Processing models: 100%|██████████| 5/5 [00:20<00:00,  4.11s/it]
# Processing row 43...
# Processing models: 100%|██████████| 5/5 [00:18<00:00,  3.63s/it]
# Processing row 44...
# Processing models: 100%|██████████| 5/5 [00:16<00:00,  3.26s/it]

# %%
df_new.describe()
# Out:
#               No  LLM_JUDGE_Claude_score  LLM_JUDGE_Qwen_score  \
# count  45.000000               45.000000             45.000000
# mean   23.000000                0.858889              0.628889
# std    13.133926                0.079264              0.287325
# min     1.000000                0.700000              0.000000
# 25%    12.000000                0.800000              0.700000
# 50%    23.000000                0.900000              0.700000
# 75%    34.000000                0.900000              0.800000
# max    45.000000                1.000000              0.900000
#
#        LLM_JUDGE_GPT_score  LLM_JUDGE_Deepseek_RAG_score  \
# count            45.000000                     45.000000
# mean              0.757778                      0.771111
# std               0.194806                      0.209569
# min               0.100000                      0.000000
# 25%               0.700000                      0.700000
# 50%               0.800000                      0.800000
# 75%               0.900000                      0.900000
# max               0.900000                      1.000000
#
#        LLM_JUDGE_Deepseek_nonRAG_score
# count                        45.000000
# mean                          0.686667
# std                           0.293567
# min                           0.000000
# 25%                           0.700000
# 50%                           0.800000
# 75%                           0.900000
# max                           1.000000
